# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional satatements
# 2. `if`
# 3.  statement
# 4. 'elif' statement
# 5. 'eles' statement
# 6. 'insted' statement
#
# ``` python _if
# if (condition): #if conditions true inside stotements are running
#    statement1
#    statement````
# `````
#
# ````` python _ if else
# if (conditions): #if condition true inside the statement
#     statement1
#     statement`````
# ``````
# else: #if conditions fails its went to else statement and  printing inside statements
#     statement1
#     statement````
# ``````
#
# ````` python _ if,else,

# %%
# write a program to find the given number is even number?
number=int (input("enter numbers here:"))
if (number%2 == 0):
    print(number, "is even number")
# Out:
# enter numbers here: 86
# 86 is even number

# %%
1020%2
# Out:
# 0

# %%
# write program to find the given number is even number or odd number?
num = int(input("please enter number here:"))
if (num%2 ==1):
    print(num,"is even number")
else:
    print(num,"is even number")
# Out:
# please enter number here: 8642
# 8642 is even number

# %%
# write a program to find the given number is postive or negitive or zero?
num = int(input("please enter number here:"))
if (num>0):
    print(num,"is postive number")
elif (num<0):
    print(num,"is negitive number")
else:
    print(num,"is zero")
# Out:
# please enter number here: 76
# 76 is postive number

# %%
# write a program to find the largest number from three number?
v1=int(input("enter first number here:"))
v2=int(input("enter second number here:"))
v3=int(input("enter third number here:"))
if (v1>v2 and v1>v3):
    print(v1,"is the largest number")
elif (v2>v3 and v2<v1):
    print(v2,"is the largest number")
else:
    print(v3,"is the largest number")
# Out:
# enter first number here: 76
# enter second number here: 76
# enter third number here: 67
# 67 is the largest number

# %%
""""
write a program to find the grade based on student marks 
1. if marks in between 80 to 100 _A Grade 
2. if marks in between 60 to 79 _B Grade  
3. if marks in between 40 to 59 _C Grade 
4. if marks in between 25 to 39 _D Grade 
5. if marks in between 0 to 55 _ Fail
6. if other than out put marks _ please enter correct marks
"""
marks = int(input("enter students marks here:"))
elif (marks >=80and marke <=100)
   print(marks ,"A Grade")
elif (marks >=60and marke <=79)
    print(marks ,"B Grade")
elif (marks >=40and marke <=59)
    print(marks ,"C Grade")
elif (marks >=25and marke <=39)
    print(marks ,"D Grade")
elif (marks >=0and marke <=24)
    print(marks ,"is Fail")
else:
    print("please enter correct marks")
# Out:
# <>:11: SyntaxWarning: invalid decimal literal
# <>:13: SyntaxWarning: invalid decimal literal
# <>:15: SyntaxWarning: invalid decimal literal
# <>:17: SyntaxWarning: invalid decimal literal
# <>:19: SyntaxWarning: invalid decimal literal
# <>:11: SyntaxWarning: invalid decimal literal
# <>:13: SyntaxWarning: invalid decimal literal
# <>:15: SyntaxWarning: invalid decimal literal
# <>:17: SyntaxWarning: invalid decimal literal
# <>:19: SyntaxWarning: invalid decimal literal
# C:\Users\badri\AppData\Local\Temp\ipykernel_16820\595357236.py:11: SyntaxWarning: invalid decimal literal
#   elif (marks >=80and marke <=100)
# C:\Users\badri\AppData\Local\Temp\ipykernel_16820\595357236.py:13: SyntaxWarning: invalid decimal literal
#   elif (marks >=60and marke <=79)
# C:\Users\badri\AppData\Local\Temp\ipykernel_16820\595357236.py:15: SyntaxWarning: invalid decimal literal
#   elif (marks >=40and marke <=59)
# ...

# %%
#write a program to Voild Login credentoils using conditional statement
username=str(input("please enter usearname here:"))
if (username=="havisha@123"):
    print ("username is valid")
    password=str(input("please enter password here:"))
    if (password=="2424"):
    print("user credentilas successfully Valid")
    else:
    print ("passwort invalid")
else:
    print("username is invalid")
